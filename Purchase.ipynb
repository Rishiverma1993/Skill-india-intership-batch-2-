# %%
import json

data = open("record.json", 'r')
text = data.read()
data.close()

record = json.loads(text)

# %%
record
# Out:
# {'1001': {'Name': 'Amul Ghee',
#   'Quntity': 5,
#   'Manuf_data': '10aug2020',
#   'Exp_data': '03oct2021',
#   'Price': 750},
#  '1002': {'Name': 'KitKat',
#   'Quntity': 52,
#   'Manuf_data': '02aug2020',
#   'Exp_data': '10oct2021',
#   'Price': 50},
#  '1003': {'Name': 'Milk',
#   'Quntity': 10,
#   'Manuf_data': '01aug2020',
#   'Exp_data': '11oct2021',
#   'Price': 60},
#  '1004': {'Name': 'Rice',
#   'Quntity': 90,
#   'Manuf_data': '06aug2020',
#   'Exp_data': '17oct2021',
#   'Price': 500},
#  '1005': {'Name': 'Daal',
#   'Quntity': 70,
#   'Manuf_data': '07aug2020',
#   'Exp_data': '10oct2021',
#   'Price': 320},
#  '1006': {'Name': 'Cornflore',
#   'Quntity': 50,
#   'Manuf_data': '12aug2020',
#   'Exp_data': '10oct2021',
#   'Price': 79},
#  '1007': {'Name': 'Protin',
#   'Quntity': 30,
#   'Manuf_data': '22aug2020',
#   'Exp_data': '10oct2022',
#   'Price': 90},
#  '1008': {'Name': 'Allmond Oil',
#   'Quntity': 10,
#   'Manuf_data': '21aug2020',
# ...

# %%
import time
Purchase = {}

# %%
User_id = str(input("Enter the product ID: "))


if (User_id in record.keys()):  
    print("In stock ,name of product: ",record[User_id]['Name'])
    print("Total quntity in store : ",record[User_id]['Quntity'])
    User_qn = int(input("Enter the quntity do you want: "))
    if (record[User_id]['Quntity'] >= User_qn):
        
        print("*********************************************************************")
        User_Name = str(input("Customer name: "))
        User_Phone = str(input("Customer Contact: "))
        print("Product: " ,record[User_id]['Name'])
        print("Price of single item: ",record[User_id]['Price'])
        
        print("Quntity: " ,User_qn)
        print("Total amount: ",(record[User_id]['Price'] * User_qn))
        print("Mode of Payment (cash/card)")
        print("------NOTE-----10% discount on card payment")
        
        ch =  str(input("card/cash"))
        
        if(ch == "card"):
            print("**************card payment***************************************")
            
            print("Total amount: ",(record[User_id]['Price'] * User_qn))
            print("Total Discount :",(record[User_id]['Price'] * User_qn)/10)
            print("billing amount: " ,(record[User_id]['Price'] * User_qn) - (record[User_id]['Price'] * User_qn)/10)
            
            cd = str(input("purchase order(Yes/No)"))
            
            if(cd == "Yes"):
                print("***********Customer recipt*************")
                print("time : ",time.ctime())
                print("Product: " ,record[User_id]['Name'])
                print("Quntity: " ,User_qn)
                print("Customer name: ",User_Name)
                print("Customer contact: ",User_Phone)
                print("pay amount: ",(record[User_id]['Price'] * User_qn) - (record[User_id]['Price'] * User_qn)/10)
                
                print("Thankyou for purchasing!!!!!!!")
                
                print("***********Recode detail*************")
                record[User_id]['Quntity'] = record[User_id]['Quntity'] - User_qn

                print("Name of the product: ",record[User_id]['Name'])

                print("Left Quntity: ",record[User_id]['Quntity'])
                print("***********Purchase Updated sussefully*************")
                
                Purchase[str(len(Purchase)+1)] = {'Customer name':User_Name,'Contact':User_Phone,'Product':User_id ,'Name_of_product':record[User_id]['Name'],
                  'Quntity':User_qn, 'Amount':record[User_id]['Price'] * User_qn,"time":time.ctime()}
                
            else:
                print("Order cancel")
        else:
            print("****************cash payment*****************************************************")
            print("In cash payable amount: ", (record[User_id]['Price'] * User_qn))
            
            cd = str(input("purchase order(Yes/No)"))
            
            if(cd == "Yes"):
                print("***********Customer recipt*************")
                print("time : ",time.ctime())
                print("Product: " ,record[User_id]['Name'])
                print("Quntity: " ,User_qn)
                
                print("Customer name: ",User_Name)
                print("Customer contact: ",User_Phone)
                print("pay amount: ",(record[User_id]['Price'] * User_qn) - (record[User_id]['Price'] * User_qn)/10)
                print("****************************************")
                print("Thankyou for purchasing!!!!!!!")
                print("***********Recode detail*************")
                record[User_id]['Quntity'] = record[User_id]['Quntity'] - User_qn

                print("Name of the product: ",record[User_id]['Name'])

                print("Left Quntity: ",record[User_id]['Quntity'])
                
                print("***********Purchase Updated sussefully*************")
                
                Purchase[str(len(Purchase)+1)] = {'Customer name':User_Name,'Contact':User_Phone,'Product':User_id ,'Name_of_product':record[User_id]['Name'],
                  'Quntity':User_qn, 'Amount':record[User_id]['Price'] * User_qn,"time":time.ctime()}
            else:
                print("Order cancel")
    else:
        print("we don't have much quntity")
        print("we have only:",record[User_id]['Quntity']) 
        print("Would you like to purchase or not (Y/N)")
        ch = str(input("Y/N"))  
              
        if (ch == "Y"):
                new_quntiy = int(input("Re-enter Quntity"))
                User_Name = str(input("Customer name: "))
                User_Phone = str(input("Customer Contact: "))
                print("Product: " ,record[User_id]['Name'])
                print("Price of single item: ",record[User_id]['Price'])
        
                print("Quntity: " ,new_quntiy)
                print("Total amount: ",(record[User_id]['Price'] * new_quntiy))
                print("Mode of Payment (cash/card)")
                print("------NOTE-----10% discount on card payment")
                    
                ch =  str(input("card/cash"))
        
                if(ch == "card"):
                    print("**************card payment***************************************")
                    print("Total amount: ",(record[User_id]['Price'] * new_quntiy))
                    print("Total Discount :",(record[User_id]['Price'] * new_quntiy)/10)
                    print("Pay amount: " ,(record[User_id]['Price'] * new_quntiy) - (record[User_id]['Price'] * new_quntiy)/10)
                    cd = str(input("Purchase order(Yes/No)"))
            
                    if(cd == "Yes"):
                        print("*********************************************************************")
                        print("***********Customer recipt*************")
                        print("time : ",time.ctime())
                        print("Product: " ,record[User_id]['Name'])
                        print("Quntity: " ,new_quntiy)
                        print("Customer name: ",User_Name)
                        print("Customer contact: ",User_Phone)
                        print("pay amount: ",(record[User_id]['Price'] * new_quntiy) - (record[User_id]['Price'] * new_quntiy)/10)
                        print("***********Recode detail*************")
                        record[User_id]['Quntity'] = record[User_id]['Quntity'] - new_quntiy

                        print("Name of the product: ",record[User_id]['Name'])

                        print("Left Quntity: ",record[User_id]['Quntity'])
                        print("***********Purchase Updated sussefully*************")
                
                        Purchase[str(len(Purchase)+1)] = {'Customer name':User_Name,'Contact':User_Phone,'Product':User_id ,'Name_of_product':record[User_id]['Name'],
                                                          'Quntity':User_qn, 'Amount':record[User_id]['Price'] * User_qn,"time":time.ctime()}
               
                
                
                        print("Thankyou for purchasing!!!!!!!")
                       
                    else:
                        print("!!!!!Order cancel!!!!!")
                    
                    
                    
                    
                else:
                    print("****************cash payment*****************************************************")
                    
                    print("Product: " ,record[User_id]['Name'])
                    
        
                    print("Quntity: " ,new_quntiy)
                    print("NO discount")
                    print("Total amount pay: ", (record[User_id]['Price'] * new_quntiy))
                    
                    cd = str(input("Purchase order(Yes/No)"))
            
                    if(cd == "Yes"):
                        print("***********Customer recipt*************")
                        print("time : ",time.ctime())
                        print("Product: " ,record[User_id]['Name'])
                        print("Quntity: " ,new_quntiy)
                
                        print("Customer name: ",User_Name)
                        print("Customer contact: ",User_Phone)
                        print("pay amount: ",(record[User_id]['Price'] * new_quntiy) - (record[User_id]['Price'] * new_quntiy)/10)
                        print("****************************************")
                        print("Thankyou for purchasing!!!!!!!")
                        print("***********update inventeri*************")
                        record[User_id]['Quntity'] = record[User_id]['Quntity'] - new_quntiy

                        print("Name of the product: ",record[User_id]['Name'])

                        print("Left Quntity: ",record[User_id]['Quntity'])
                        
                        print("***********Purchase Updated sussefully*************")
                
                        Purchase[str(len(Purchase)+1)] = {'Customer name':User_Name,'Contact':User_Phone,'Product':User_id ,'Name_of_product':record[User_id]['Name'],
                                                          'Quntity':User_qn, 'Amount':record[User_id]['Price'] * User_qn,"time":time.ctime()}                        
                    else:
                        print("!!!!!Order cancel!!!!!")
                    
                    
        else:
            print("!!!!Thankyou!!!!")
    print("*********************************************************************")
            

     
      

else:
    print("------------------------------")
    print("Product doesn't exist!")
    print("Please enter a valid product id")
    print("------------------------------")
    



Transaction = json.dumps(Purchase)

file = open("Purchase.json",'w')
file.write(Transaction)
file.close()

print("Data Updated in Sales File!")


js = json.dumps(record)                                                            # Updating Inventory File
fd = open('record.json','w')
fd.write(js)
fd.close()

print("Data Updated in Inventory File!")
# Out:
# Enter the product ID:  1010
# In stock ,name of product:  Bread
# Total quntity in store :  55
# Enter the quntity do you want:  2
# *********************************************************************
# Customer name:  Morgan
# Customer Contact:  03935535532
# Product:  Bread
# Price of single item:  70
# Quntity:  2
# Total amount:  140
# Mode of Payment (cash/card)
# ------NOTE-----10% discount on card payment
# card/cash card
# **************card payment***************************************
# Total amount:  140
# Total Discount : 14.0
# billing amount:  126.0
# purchase order(Yes/No) Yes
# ***********Customer recipt*************
# time :  Fri Sep 10 14:08:43 2021
# Product:  Bread
# Quntity:  2
# Customer name:  Morgan
# Customer contact:  03935535532
# pay amount:  126.0
# Thankyou for purchasing!!!!!!!
# ***********Recode detail*************
# Name of the product:  Bread
# Left Quntity:  53
# ***********Purchase Updated sussefully*************
# ...

# %%
Purchase
# Out:
# {'1': {'Customer name': 'beena',
#   'Contact': '990129203',
#   'Product': '1011',
#   'Name_of_product': 'Peenut',
#   'Quntity': 12,
#   'Amount': 4680,
#   'time': 'Fri Sep 10 14:06:49 2021'},
#  '2': {'Customer name': 'Morgan',
#   'Contact': '03935535532',
#   'Product': '1010',
#   'Name_of_product': 'Bread',
#   'Quntity': 2,
#   'Amount': 140,
#   'time': 'Fri Sep 10 14:08:43 2021'}}

# %% [raw]
# record['1010']

# %%
record['1010']
# Out:
# {'Name': 'Bread',
#  'Quntity': 53,
#  'Manuf_data': '01aug2021',
#  'Exp_data': '03aug2021',
#  'Price': 70}
